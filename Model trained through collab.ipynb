# %% [markdown]
# <a href="https://colab.research.google.com/github/DemonWillCode/Demo-Dashboard/blob/main/Model%20trained%20through%20collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Libraries and Dependencies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Importing Scikit-learn Libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# Data Manipulation

# %%
data = pd.read_csv('Mumbai.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7719 entries, 0 to 7718
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Price                7719 non-null   int64
#  1   Area                 7719 non-null   int64
#  2   Location             7719 non-null   object
#  3   No. of Bedrooms      7719 non-null   int64
#  4   Resale               7719 non-null   int64
#  5   MaintenanceStaff     7719 non-null   int64
#  6   Gymnasium            7719 non-null   int64
#  7   SwimmingPool         7719 non-null   int64
#  8   LandscapedGardens    7719 non-null   int64
#  9   JoggingTrack         7719 non-null   int64
#  10  RainWaterHarvesting  7719 non-null   int64
#  11  IndoorGames          7719 non-null   int64
#  12  ShoppingMall         7719 non-null   int64
#  13  Intercom             7719 non-null   int64
#  14  SportsFacility       7719 non-null   int64
# ...

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7719 entries, 0 to 7718
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Price                7719 non-null   int64
#  1   Area                 7719 non-null   int64
#  2   Location             7719 non-null   object
#  3   No. of Bedrooms      7719 non-null   int64
#  4   Resale               7719 non-null   int64
#  5   MaintenanceStaff     7719 non-null   int64
#  6   Gymnasium            7719 non-null   int64
#  7   SwimmingPool         7719 non-null   int64
#  8   LandscapedGardens    7719 non-null   int64
#  9   JoggingTrack         7719 non-null   int64
#  10  RainWaterHarvesting  7719 non-null   int64
#  11  IndoorGames          7719 non-null   int64
#  12  ShoppingMall         7719 non-null   int64
#  13  Intercom             7719 non-null   int64
#  14  SportsFacility       7719 non-null   int64
# ...

# %%
X = data.drop(['Price'], axis=1)
y = data['Price']
X = pd.get_dummies(X, columns=['Location'], drop_first=True)
X
# Out:
#       Area  No. of Bedrooms  Resale  MaintenanceStaff  Gymnasium  \
# 0      720                1       1                 1          0
# 1      600                1       1                 1          1
# 2      650                1       1                 1          1
# 3      650                1       1                 1          0
# 4      665                1       1                 1          0
# ...    ...              ...     ...               ...        ...
# 7714  1180                2       0                 9          9
# 7715   530                1       1                 9          9
# 7716   700                1       0                 9          9
# 7717   995                2       0                 9          9
# 7718  1020                2       0                 9          9
#
#       SwimmingPool  LandscapedGardens  JoggingTrack  RainWaterHarvesting  \
# 0                0                  0             0                    0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
train_data = (X_train.join(y_train))
train_data
# Out:
#       Area  No. of Bedrooms  Resale  MaintenanceStaff  Gymnasium  \
# 1817  1100                2       1                 9          9
# 4298   900                2       1                 9          9
# 836    820                2       1                 0          1
# 1145   657                1       1                 0          1
# 6433  1350                2       1                 9          9
# ...    ...              ...     ...               ...        ...
# 4127   510                1       1                 9          9
# 3856   625                1       1                 9          9
# 6020  1250                2       0                 9          9
# 795   1100                3       1                 1          0
# 6983   550                1       0                 9          9
#
#       SwimmingPool  LandscapedGardens  JoggingTrack  RainWaterHarvesting  \
# 1817             9                  9             9                    9
# ...

# %% [markdown]
# Building the Linear Regression Model

# %%
X_train, y_train = train_data.drop(['Price'], axis=1), train_data['Price']

reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

test_score = reg.score(X_test, y_test)
print(f"R-squared (Test Data): {test_score}")

mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# R-squared (Test Data): 0.23572143103480425
# Mean Squared Error: 292534237638417.25

# %% [markdown]
# Exploring Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(X_test, y_test)
# Out:
# 0.28057122899700826
